# %%
pip install metpy

# %%
import numpy as np
from numpy import *
import xarray as xr
import metpy
import pandas as pd
import matplotlib.pyplot as plt

# %%
conda install conda-forge::xcdat

# %%
path = "C:/Users/Hp/Downloads/chirps-v2.0.2020.days_p05.nc"
chirps = xr.open_dataset(path)
chirps
# Out:
# C:\Users\Hp\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,
# <xarray.Dataset>
# Dimensions:    (latitude: 84, longitude: 154, time: 366)
# Coordinates:
#   * latitude   (latitude) float32 26.32 26.38 26.42 26.47 ... 30.38 30.42 30.47
#   * longitude  (longitude) float32 80.52 80.58 80.62 80.67 ... 88.08 88.12 88.17
#   * time       (time) datetime64[ns] 2020-01-01 2020-01-02 ... 2020-12-31
# Data variables:
#     precip     (time, latitude, longitude) float32 ...
# Attributes: (12/15)
#     Conventions:       CF-1.6
#     title:             CHIRPS Version 2.0
#     history:           created by Climate Hazards Group
#     version:           Version 2.0
#     date_created:      2021-01-19
#     creator_name:      Pete Peterson
#     ...                ...
#     reference:         Funk, C.C., Peterson, P.J., Landsfeld, M.F., Pedreros,...
# ...
